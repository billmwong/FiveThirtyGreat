# %%
import requests
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


court = plt.imread("fullcourt.png")

# %%
plt.figure(figsize=(15, 11.5))
plt.imshow(court, zorder=0, extent=[0,94,50,0])

plt.plot(5.32, 24.8, 'ro')
plt.plot(88.55, 24.8, 'ro')

plt.plot(47, 24.8, 'ro')

plt.xlim(0,101)
plt.show()
